# %% [markdown]
# ## Data Understanding and Pre-Processing

# %%
import pandas as pd
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import association_rules

# %%
df = pd.read_csv("Groceries_dataset.csv")
df.head(10)
# Out:
#    Member_number        Date   itemDescription
# 0           1808  21-07-2015    tropical fruit
# 1           2552  05-01-2015        whole milk
# 2           2300  19-09-2015         pip fruit
# 3           1187  12-12-2015  other vegetables
# 4           3037  01-02-2015        whole milk
# 5           4941  14-02-2015        rolls/buns
# 6           4501  08-05-2015  other vegetables
# 7           3803  23-12-2015        pot plants
# 8           2762  20-03-2015        whole milk
# 9           4119  12-02-2015    tropical fruit

# %%
df.shape
# Out:
# (38765, 3)

# %%
df.isnull().sum()
# Out:
# Member_number      0
# Date               0
# itemDescription    0
# dtype: int64

# %%
df.isnull().values.any()
# Out:
# False

# %%
df.dtypes
# Out:
# Member_number       int64
# Date               object
# itemDescription    object
# dtype: object

# %%
df.nunique()
# Out:
# Member_number      3898
# Date                728
# itemDescription     167
# dtype: int64

# %% [markdown]
# GroupBy Member_number and Date and convert to a list

# %%
theList = list(df.groupby(['Member_number','Date']))
theList
# Out:
# [((1000, '15-03-2015'),
#          Member_number        Date      itemDescription
#   4843            1000  15-03-2015              sausage
#   8395            1000  15-03-2015           whole milk
#   20992           1000  15-03-2015  semi-finished bread
#   24544           1000  15-03-2015               yogurt),
#  ((1000, '24-06-2014'),
#          Member_number        Date itemDescription
#   13331           1000  24-06-2014      whole milk
#   29480           1000  24-06-2014          pastry
#   32851           1000  24-06-2014     salty snack),
#  ((1000, '24-07-2015'),
#          Member_number        Date  itemDescription
#   2047            1000  24-07-2015      canned beer
#   18196           1000  24-07-2015  misc. beverages),
#  ((1000, '25-11-2015'),
#          Member_number        Date   itemDescription
#   6388            1000  25-11-2015           sausage
#   22537           1000  25-11-2015  hygiene articles),
#  ((1000, '27-05-2015'),
#          Member_number        Date     itemDescription
#   1629            1000  27-05-2015                soda
#   17778           1000  27-05-2015  pickled vegetables),
#  ((1001, '02-05-2015'),
#          Member_number        Date itemDescription
#   5695            1001  02-05-2015     frankfurter
#   21844           1001  02-05-2015            curd),
#  ((1001, '07-02-2014'),
#          Member_number        Date itemDescription
#   9391            1001  07-02-2014         sausage
#   25540           1001  07-02-2014      whole milk
#   32727           1001  07-02-2014      rolls/buns),
#  ((1001, '12-12-2014'),
#          Member_number        Date itemDescription
#   11046           1001  12-12-2014      whole milk
#   27195           1001  12-12-2014            soda),
#  ((1001, '14-04-2015'),
#          Member_number        Date itemDescription
#   6612            1001  14-04-2015            beef
#   22761           1001  14-04-2015     white bread),
#  ((1001, '20-01-2015'),
#          Member_number        Date     itemDescription
#   364             1001  20-01-2015         frankfurter
#   16513           1001  20-01-2015                soda
#   32575           1001  20-01-2015  whipped/sour cream),
#  ((1002, '09-02-2014'),
#          Member_number        Date    itemDescription
#   15386           1002  09-02-2014  frozen vegetables
#   31535           1002  09-02-2014   other vegetables),
#  ((1002, '26-04-2014'),
#          Member_number        Date itemDescription
#   11209           1002  26-04-2014          butter
#   27358           1002  26-04-2014      whole milk),
#  ((1002, '26-04-2015'),
#          Member_number        Date itemDescription
#   4255            1002  26-04-2015  tropical fruit
#   20404           1002  26-04-2015           sugar),
#  ((1002, '30-08-2015'),
#          Member_number        Date      itemDescription
#   4917            1002  30-08-2015          butter milk
#   21066           1002  30-08-2015  specialty chocolate),
#  ((1003, '10-02-2015'),
#          Member_number        Date itemDescription
#   5729            1003  10-02-2015         sausage
#   21878           1003  10-02-2015      rolls/buns),
#  ((1003, '15-10-2014'),
#          Member_number        Date  itemDescription
#   11057           1003  15-10-2014  root vegetables
#   27206           1003  15-10-2014        detergent),
#  ((1003, '19-01-2014'),
#          Member_number        Date itemDescription
#   33021           1003  19-01-2014    frozen meals
#   37572           1003  19-01-2014     dental care),
#  ((1003, '27-02-2014'),
#          Member_number        Date itemDescription
#   33098           1003  27-02-2014      rolls/buns
#   37649           1003  27-02-2014      rolls/buns),
#  ((1004, '01-05-2014'),
#          Member_number        Date  itemDescription
#   33795           1004  01-05-2014     dish cleaner
#   38346           1004  01-05-2014  cling film/bags),
#  ((1004, '01-07-2014'),
#          Member_number        Date itemDescription
#   12114           1004  01-07-2014     canned beer
#   28263           1004  01-07-2014     frozen fish),
#  ((1004, '02-12-2015'),
#          Member_number        Date   itemDescription
#   4936            1004  02-12-2015  other vegetables
#   21085           1004  02-12-2015  hygiene articles),
#  ((1004, '04-02-2014'),
#          Member_number        Date itemDescription
#   10792           1004  04-02-2014       pip fruit
#   26941           1004  04-02-2014      whole milk
#   34199           1004  04-02-2014  tropical fruit),
#  ((1004, '10-06-2014'),
#          Member_number        Date itemDescription
#   12293           1004  10-06-2014      rolls/buns
#   28442           1004  10-06-2014  red/blush wine
#   38519           1004  10-06-2014       chocolate),
#  ((1004, '10-07-2014'),
#          Member_number        Date   itemDescription
#   14500           1004  10-07-2014  other vegetables
#   30649           1004  10-07-2014     shopping bags),
#  ((1004, '13-10-2014'),
#          Member_number        Date            itemDescription
#   13767           1004  13-10-2014                 whole milk
#   29916           1004  13-10-2014                  chocolate
#   33897           1004  13-10-2014  packaged fruit/vegetables
#   37214           1004  13-10-2014                 rolls/buns),
#  ((1004, '19-08-2014'),
#          Member_number        Date  itemDescription
#   11398           1004  19-08-2014  root vegetables
#   27547           1004  19-08-2014       whole milk
#   38641           1004  19-08-2014           pastry),
#  ((1005, '09-01-2014'),
#          Member_number        Date itemDescription
#   15099           1005  09-01-2014      rolls/buns
#   31248           1005  09-01-2014      rolls/buns),
#  ((1005, '23-01-2014'),
#          Member_number        Date     itemDescription
#   14185           1005  23-01-2014  whipped/sour cream
#   30334           1005  23-01-2014           margarine),
#  ((1006, '05-07-2014'),
#          Member_number        Date itemDescription
#   14021           1006  05-07-2014   bottled water
#   30170           1006  05-07-2014        softener
#   34151           1006  05-07-2014      rolls/buns),
#  ((1006, '09-04-2014'),
#          Member_number        Date itemDescription
#   8868            1006  09-04-2014      whole milk
#   25017           1006  09-04-2014            rice),
#  ((1006, '11-07-2014'),
#          Member_number        Date itemDescription
#   33879           1006  11-07-2014   shopping bags
#   38430           1006  11-07-2014       skin care),
#  ((1006, '14-06-2015'),
#          Member_number        Date itemDescription
#   2155            1006  14-06-2015      whole milk
#   7532            1006  14-06-2015     frankfurter
#   7886            1006  14-06-2015         chicken
#   8488            1006  14-06-2015     frankfurter
#   18304           1006  14-06-2015           flour
#   23681           1006  14-06-2015       chocolate
#   24035           1006  14-06-2015    bottled beer
#   24637           1006  14-06-2015      rolls/buns),
#  ((1008, '03-10-2015'),
#          Member_number        Date     itemDescription
#   3925            1008  03-10-2015      hamburger meat
#   15838           1008  03-10-2015  liquor (appetizer)
#   20074           1008  03-10-2015          liver loaf
#   31987           1008  03-10-2015             dessert),
#  ((1008, '21-07-2015'),
#          Member_number        Date  itemDescription
#   4050            1008  21-07-2015   tropical fruit
#   5061            1008  21-07-2015             soda
#   16100           1008  21-07-2015           yogurt
#   20199           1008  21-07-2015  root vegetables
#   21210           1008  21-07-2015           yogurt
#   32249           1008  21-07-2015    domestic eggs
#   36039           1008  21-07-2015       white wine
#   36245           1008  21-07-2015       photo/film),
#  ((1009, '05-10-2015'),
#          Member_number        Date itemDescription
#   2496            1009  05-10-2015           herbs
#   18645           1009  05-10-2015          yogurt
#   37064           1009  05-10-2015      newspapers),
#  ((1009, '14-05-2015'),
#          Member_number        Date itemDescription
#   6209            1009  14-05-2015  tropical fruit
#   22358           1009  14-05-2015          yogurt),
#  ((1009, '23-09-2015'),
#          Member_number        Date itemDescription
#   2614            1009  23-09-2015          pastry
#   18763           1009  23-09-2015         ketchup),
#  ((1009, '24-01-2014'),
#          Member_number        Date itemDescription
#   33384           1009  24-01-2014     canned fish
#   37935           1009  24-01-2014    cocoa drinks),
#  ((1010, '05-03-2014'),
#          Member_number        Date itemDescription
#   12965           1010  05-03-2014       pip fruit
#   29114           1010  05-03-2014          coffee
#   36964           1010  05-03-2014        UHT-milk),
#  ((1010, '10-04-2014'),
#          Member_number        Date itemDescription
#   33367           1010  10-04-2014  kitchen towels
#   37918           1010  10-04-2014   sliced cheese),
#  ((1010, '23-08-2014'),
#          Member_number        Date itemDescription
#   13135           1010  23-08-2014   bottled water
#   29284           1010  23-08-2014   specialty bar),
#  ((1010, '27-08-2014'),
#          Member_number        Date itemDescription
#   9604            1010  27-08-2014     frankfurter
#   25753           1010  27-08-2014   bottled water),
#  ((1010, '31-07-2015'),
#          Member_number        Date itemDescription
#   3430            1010  31-07-2015       pip fruit
#   19579           1010  31-07-2015         candles
#   34737           1010  31-07-2015      rolls/buns),
#  ((1011, '02-06-2014'),
#          Member_number        Date itemDescription
#   14319           1011  02-06-2014     curd cheese
#   30468           1011  02-06-2014          pastry),
#  ((1011, '09-12-2015'),
#          Member_number        Date   itemDescription
#   2099            1011  09-12-2015        whole milk
#   7476            1011  09-12-2015       frankfurter
#   7830            1011  09-12-2015           candles
#   18248           1011  09-12-2015            grapes
#   23625           1011  09-12-2015             herbs
#   23979           1011  09-12-2015  other vegetables
#   35140           1011  09-12-2015            yogurt),
#  ((1011, '15-02-2014'),
#          Member_number        Date itemDescription
#   10317           1011  15-02-2014    citrus fruit
#   26466           1011  15-02-2014           candy
#   34533           1011  15-02-2014   bottled water
#   35355           1011  15-02-2014      rolls/buns),
#  ((1012, '03-10-2015'),
#          Member_number        Date itemDescription
#   1831            1012  03-10-2015     frankfurter
#   17980           1012  03-10-2015          yogurt),
#  ((1012, '19-11-2015'),
#          Member_number        Date  itemDescription
#   2851            1012  19-11-2015   tropical fruit
#   7248            1012  19-11-2015  root vegetables
#   19000           1012  19-11-2015       rolls/buns
#   23397           1012  19-11-2015           onions
#   34912           1012  19-11-2015    shopping bags),
#  ((1012, '22-06-2014'),
#          Member_number        Date    itemDescription
#   33150           1012  22-06-2014  frozen vegetables
#   37701           1012  22-06-2014        brown bread),
#  ((1012, '27-03-2015'),
#          Member_number        Date   itemDescription
#   2385            1012  27-03-2015  processed cheese
#   18534           1012  27-03-2015        whole milk),
#  ((1013, '02-07-2015'),
#          Member_number        Date itemDescription
#   2787            1013  02-07-2015    frozen meals
#   18936           1013  02-07-2015      whole milk),
#  ((1013, '02-10-2015'),
#          Member_number        Date itemDescription
#   3610            1013  02-10-2015     white bread
#   8581            1013  02-10-2015            meat
#   19759           1013  02-10-2015   domestic eggs
#   24730           1013  02-10-2015  roll products ),
#  ((1013, '12-11-2014'),
#          Member_number        Date  itemDescription
#   13056           1013  12-11-2014  root vegetables
#   29205           1013  12-11-2014       mayonnaise),
#  ((1013, '15-07-2014'),
#          Member_number        Date   itemDescription
#   14795           1013  15-07-2014  other vegetables
#   30944           1013  15-07-2014           mustard),
#  ((1013, '17-01-2014'),
#          Member_number        Date itemDescription
#   12276           1013  17-01-2014     hard cheese
#   28425           1013  17-01-2014         napkins
#   38502           1013  17-01-2014   bottled water),
#  ((1013, '20-02-2014'),
#          Member_number        Date itemDescription
#   8851            1013  20-02-2014      whole milk
#   25000           1013  20-02-2014           candy),
#  ((1013, '26-03-2014'),
#          Member_number        Date    itemDescription
#   11788           1013  26-03-2014     tropical fruit
#   27937           1013  26-03-2014  frozen vegetables),
#  ((1013, '28-03-2014'),
#          Member_number        Date     itemDescription
#   11894           1013  28-03-2014             mustard
#   28043           1013  28-03-2014  whipped/sour cream),
#  ((1014, '03-10-2015'),
#          Member_number        Date itemDescription
#   4812            1014  03-10-2015      whole milk
#   8364            1014  03-10-2015         sausage
#   20961           1014  03-10-2015    bottled beer
#   24513           1014  03-10-2015          yogurt),
#  ((1014, '04-01-2015'),
#          Member_number        Date itemDescription
#   6481            1014  04-01-2015     canned beer
#   22630           1014  04-01-2015        cookware),
#  ((1014, '04-09-2014'),
#          Member_number        Date itemDescription
#   14228           1014  04-09-2014  hamburger meat
#   30377           1014  04-09-2014     butter milk),
#  ((1014, '06-10-2014'),
#          Member_number        Date itemDescription
#   14543           1014  06-10-2014      whole milk
#   30692           1014  06-10-2014      rolls/buns),
#  ((1015, '04-05-2015'),
#          Member_number        Date itemDescription
#   1309            1015  04-05-2015    citrus fruit
#   17458           1015  04-05-2015      whole milk),
#  ((1015, '22-03-2015'),
#          Member_number        Date itemDescription
#   6421            1015  22-03-2015     salty snack
#   22570           1015  22-03-2015            beef),
#  ((1015, '28-06-2014'),
#          Member_number        Date        itemDescription
#   10906           1015  28-06-2014  fruit/vegetable juice
#   27055           1015  28-06-2014             rolls/buns
#   34313           1015  28-06-2014              chocolate),
#  ((1016, '05-10-2015'),
#          Member_number        Date itemDescription
#   970             1016  05-10-2015        UHT-milk
#   17119           1016  05-10-2015    bottled beer),
#  ((1016, '19-07-2015'),
#          Member_number        Date itemDescription
#   5735            1016  19-07-2015         chicken
#   21884           1016  19-07-2015  red/blush wine),
#  ((1016, '23-04-2015'),
#          Member_number        Date itemDescription
#   4338            1016  23-04-2015     soft cheese
#   20487           1016  23-04-2015       pip fruit),
#  ((1016, '30-09-2015'),
#          Member_number        Date itemDescription
#   5559            1016  30-09-2015      rolls/buns
#   7776            1016  30-09-2015     frankfurter
#   21708           1016  30-09-2015             oil
#   23925           1016  30-09-2015       pip fruit
#   36743           1016  30-09-2015      mayonnaise),
#  ((1017, '14-10-2014'),
#          Member_number        Date itemDescription
#   33131           1017  14-10-2014     brown bread
#   37682           1017  14-10-2014        pet care),
#  ((1017, '16-05-2015'),
#          Member_number        Date   itemDescription
#   6625            1017  16-05-2015  other vegetables
#   22774           1017  16-05-2015        rolls/buns),
#  ((1017, '19-06-2014'),
#          Member_number        Date itemDescription
#   10117           1017  19-06-2014          yogurt
#   26266           1017  19-06-2014            beef),
#  ((1017, '21-02-2014'),
#          Member_number        Date   itemDescription
#   15194           1017  21-02-2014  other vegetables
#   31343           1017  21-02-2014   root vegetables),
#  ((1017, '30-09-2015'),
#          Member_number        Date itemDescription
#   2469            1017  30-09-2015            soda
#   18618           1017  30-09-2015         dessert
#   37037           1017  30-09-2015   shopping bags),
#  ((1018, '01-10-2014'),
#          Member_number        Date           itemDescription
#   11917           1018  01-10-2014                      curd
#   28066           1018  01-10-2014  long life bakery product),
#  ((1018, '15-04-2014'),
#          Member_number        Date itemDescription
#   15568           1018  15-04-2014       beverages
#   31717           1018  15-04-2014   domestic eggs),
#  ((1018, '23-05-2015'),
#          Member_number        Date  itemDescription
#   1014            1018  23-05-2015      butter milk
#   17163           1018  23-05-2015  root vegetables),
#  ((1018, '27-05-2014'),
#          Member_number        Date itemDescription
#   14879           1018  27-05-2014         berries
#   31028           1018  27-05-2014        cake bar),
#  ((1019, '10-12-2014'),
#          Member_number        Date itemDescription
#   11210           1019  10-12-2014  hamburger meat
#   27359           1019  10-12-2014  red/blush wine),
#  ((1020, '12-08-2014'),
#          Member_number        Date itemDescription
#   12497           1020  12-08-2014     canned beer
#   28646           1020  12-08-2014   shopping bags),
#  ((1020, '13-10-2015'),
#          Member_number        Date itemDescription
#   5902            1020  13-10-2015     canned beer
#   16025           1020  13-10-2015          spices
#   22051           1020  13-10-2015      rolls/buns
#   32174           1020  13-10-2015     frozen fish),
#  ((1020, '19-07-2014'),
#          Member_number        Date itemDescription
#   13818           1020  19-07-2014    frozen meals
#   29967           1020  19-07-2014          butter
#   33948           1020  19-07-2014      newspapers
#   37265           1020  19-07-2014          yogurt),
#  ((1021, '07-11-2015'),
#          Member_number        Date itemDescription
#   2658            1021  07-11-2015      rolls/buns
#   18807           1021  07-11-2015   baking powder),
#  ((1021, '22-10-2015'),
#          Member_number        Date itemDescription
#   4788            1021  22-10-2015          liquor
#   8340            1021  22-10-2015            curd
#   20937           1021  22-10-2015          yogurt
#   24489           1021  22-10-2015  tropical fruit),
#  ((1021, '30-05-2014'),
#          Member_number        Date itemDescription
#   10745           1021  30-05-2014   sliced cheese
#   26894           1021  30-05-2014          butter),
#  ((1022, '07-06-2014'),
#          Member_number        Date        itemDescription
#   9328            1022  07-06-2014                sausage
#   25477           1022  07-06-2014  fruit/vegetable juice),
#  ((1022, '22-02-2014'),
#          Member_number        Date itemDescription
#   11169           1022  22-02-2014            beef
#   27318           1022  22-02-2014         napkins),
#  ((1022, '25-03-2014'),
#          Member_number        Date     itemDescription
#   15088           1022  25-03-2014          whole milk
#   31237           1022  25-03-2014  whipped/sour cream),
#  ((1023, '06-01-2015'),
#          Member_number        Date            itemDescription
#   4614            1023  06-01-2015         whipped/sour cream
#   8166            1023  06-01-2015            root vegetables
#   20763           1023  06-01-2015                 rolls/buns
#   24315           1023  06-01-2015  packaged fruit/vegetables),
#  ((1023, '13-06-2014'),
#          Member_number        Date itemDescription
#   11318           1023  13-06-2014   domestic eggs
#   27467           1023  13-06-2014            soda),
#  ((1023, '17-05-2014'),
#          Member_number        Date itemDescription
#   12681           1023  17-05-2014         chicken
#   28830           1023  17-05-2014    frozen meals),
#  ((1023, '22-05-2014'),
#          Member_number        Date itemDescription
#   14994           1023  22-05-2014  male cosmetics
#   31143           1023  22-05-2014            curd),
#  ((1023, '28-06-2015'),
#          Member_number        Date itemDescription
#   4505            1023  28-06-2015     white bread
#   8057            1023  28-06-2015    bottled beer
#   20654           1023  28-06-2015          yogurt
#   24206           1023  28-06-2015         berries),
#  ((1023, '30-12-2014'),
#          Member_number        Date     itemDescription
#   10832           1023  30-12-2014             sausage
#   26981           1023  30-12-2014  whipped/sour cream
#   34239           1023  30-12-2014       specialty bar),
#  ((1024, '10-08-2015'),
#          Member_number        Date   itemDescription
#   118             1024  10-08-2015              fish
#   7195            1024  10-08-2015   root vegetables
#   16267           1024  10-08-2015    tropical fruit
#   23344           1024  10-08-2015  other vegetables),
#  ((1025, '06-02-2014'),
#          Member_number        Date itemDescription
#   11274           1025  06-02-2014          coffee
#   27423           1025  06-02-2014   shopping bags),
#  ((1025, '10-03-2014'),
#          Member_number        Date itemDescription
#   9940            1025  10-03-2014             ham
#   26089           1025  10-03-2014   cream cheese ),
#  ((1025, '19-08-2015'),
#          Member_number        Date itemDescription
#   2042            1025  19-08-2015     canned beer
#   18191           1025  19-08-2015        UHT-milk),
#  ((1026, '08-03-2014'),
#          Member_number        Date     itemDescription
#   10281           1026  08-03-2014             sausage
#   26430           1026  08-03-2014             dessert
#   34497           1026  08-03-2014          rolls/buns
#   35319           1026  08-03-2014  pickled vegetables),
#  ((1026, '15-03-2015'),
#          Member_number        Date        itemDescription
#   2919            1026  15-03-2015  fruit/vegetable juice
#   7316            1026  15-03-2015            salty snack
#   19068           1026  15-03-2015                  candy
#   23465           1026  15-03-2015            dental care
#   34980           1026  15-03-2015                 butter),
#  ((1026, '18-06-2014'),
#          Member_number        Date           itemDescription
#   15461           1026  18-06-2014           root vegetables
#   31610           1026  18-06-2014  long life bakery product),
#  ((1026, '23-08-2014'),
#          Member_number        Date itemDescription
#   9286            1026  23-08-2014    citrus fruit
#   25435           1026  23-08-2014          yogurt),
#  ((1026, '28-05-2015'),
#          Member_number        Date     itemDescription
#   4769            1026  28-05-2015     root vegetables
#   8321            1026  28-05-2015  whipped/sour cream
#   20918           1026  28-05-2015     root vegetables
#   24470           1026  28-05-2015         canned beer),
#  ((1027, '14-05-2014'),
#          Member_number        Date itemDescription
#   10829           1027  14-05-2014        softener
#   26978           1027  14-05-2014            salt
#   34236           1027  14-05-2014      whole milk),
#  ((1027, '17-05-2015'),
#          Member_number        Date itemDescription
#   259             1027  17-05-2015            pork
#   16408           1027  17-05-2015  hamburger meat),
#  ((1027, '22-09-2014'),
#          Member_number        Date itemDescription
#   33087           1027  22-09-2014      rolls/buns
#   37638           1027  22-09-2014   bottled water),
#  ((1027, '25-02-2015'),
#          Member_number        Date itemDescription
#   5989            1027  25-02-2015      rolls/buns
#   22138           1027  25-02-2015  red/blush wine),
#  ((1028, '02-06-2015'),
#          Member_number        Date itemDescription
#   5158            1028  02-06-2015          onions
#   21307           1028  02-06-2015     canned beer
#   36342           1028  02-06-2015  flower (seeds)),
#  ((1028, '05-04-2014'),
#          Member_number        Date itemDescription
#   14132           1028  05-04-2014      rolls/buns
#   30281           1028  05-04-2014           sugar),
#  ((1028, '10-11-2014'),
#          Member_number        Date itemDescription
#   12046           1028  10-11-2014            soda
#   28195           1028  10-11-2014          butter),
#  ((1028, '11-07-2015'),
#          Member_number        Date      itemDescription
#   937             1028  11-07-2015  specialty chocolate
#   17086           1028  11-07-2015      root vegetables),
#  ((1028, '24-04-2014'),
#          Member_number        Date itemDescription
#   13807           1028  24-04-2014      rolls/buns
#   29956           1028  24-04-2014   baking powder
#   33937           1028  24-04-2014          onions
#   37254           1028  24-04-2014   bottled water),
#  ((1029, '14-03-2015'),
#          Member_number        Date itemDescription
#   1159            1029  14-03-2015         dessert
#   17308           1029  14-03-2015             ham),
#  ((1031, '04-03-2014'),
#          Member_number        Date itemDescription
#   14139           1031  04-03-2014       ice cream
#   30288           1031  04-03-2014      pot plants),
#  ((1031, '15-10-2015'),
#          Member_number        Date   itemDescription
#   3347            1031  15-10-2015  other vegetables
#   19496           1031  15-10-2015  other vegetables
#   34654           1031  15-10-2015           berries),
#  ((1031, '26-08-2015'),
#          Member_number        Date itemDescription
#   1559            1031  26-08-2015       beverages
#   17708           1031  26-08-2015   cream cheese ),
#  ((1032, '13-07-2015'),
#          Member_number        Date     itemDescription
#   6397            1032  13-07-2015           ice cream
#   22546           1032  13-07-2015  whipped/sour cream),
#  ((1032, '15-06-2015'),
#          Member_number        Date   itemDescription
#   2251            1032  15-06-2015           berries
#   7628            1032  15-06-2015              soda
#   7982            1032  15-06-2015            butter
#   18400           1032  15-06-2015  other vegetables
#   23777           1032  15-06-2015       white bread
#   24131           1032  15-06-2015     cream cheese ),
#  ((1032, '23-08-2015'),
#          Member_number        Date  itemDescription
#   4107            1032  23-08-2015           yogurt
#   20256           1032  23-08-2015  root vegetables),
#  ((1032, '23-09-2014'),
#          Member_number        Date itemDescription
#   13890           1032  23-09-2014     white bread
#   30039           1032  23-09-2014      whole milk
#   34020           1032  23-09-2014          pastry
#   37337           1032  23-09-2014   shopping bags),
#  ((1032, '26-01-2014'),
#          Member_number        Date     itemDescription
#   14854           1032  26-01-2014  whipped/sour cream
#   31003           1032  26-01-2014          newspapers),
#  ((1033, '02-03-2014'),
#          Member_number        Date itemDescription
#   8990            1033  02-03-2014     frankfurter
#   25139           1033  02-03-2014          pastry),
#  ((1033, '15-06-2015'),
#          Member_number        Date itemDescription
#   6257            1033  15-06-2015         chicken
#   22406           1033  15-06-2015         waffles),
#  ((1033, '18-04-2014'),
#          Member_number        Date        itemDescription
#   12660           1033  18-04-2014  fruit/vegetable juice
#   28809           1033  18-04-2014                dessert),
#  ((1033, '21-04-2014'),
#          Member_number        Date itemDescription
#   8739            1033  21-04-2014         sausage
#   24888           1033  21-04-2014  snack products
#   36815           1033  21-04-2014      rolls/buns),
#  ((1033, '22-04-2015'),
#          Member_number        Date itemDescription
#   271             1033  22-04-2015  tropical fruit
#   16420           1033  22-04-2015            soda
#   32482           1033  22-04-2015      rolls/buns),
#  ((1034, '13-05-2014'),
#          Member_number        Date itemDescription
#   14371           1034  13-05-2014  tropical fruit
#   30520           1034  13-05-2014      newspapers),
#  ((1034, '24-02-2014'),
#          Member_number        Date  itemDescription
#   10194           1034  24-02-2014        pip fruit
#   26343           1034  24-02-2014  cling film/bags
#   34410           1034  24-02-2014           yogurt
#   35232           1034  24-02-2014         cat food),
#  ((1034, '28-04-2014'),
#          Member_number        Date itemDescription
#   10640           1034  28-04-2014   bottled water
#   26789           1034  28-04-2014   domestic eggs
#   35678           1034  28-04-2014    frozen meals),
#  ((1035, '08-09-2015'),
#          Member_number        Date itemDescription
#   1481            1035  08-09-2015      whole milk
#   17630           1035  08-09-2015      newspapers),
#  ((1035, '15-08-2014'),
#          Member_number        Date itemDescription
#   13898           1035  15-08-2014       pip fruit
#   30047           1035  15-08-2014      white wine
#   34028           1035  15-08-2014     white bread
#   37345           1035  15-08-2014            salt),
#  ((1035, '23-05-2015'),
#          Member_number        Date    itemDescription
#   6532            1035  23-05-2015            sausage
#   22681           1035  23-05-2015  frozen vegetables),
#  ((1035, '24-04-2015'),
#          Member_number        Date itemDescription
#   3637            1035  24-04-2015      whole milk
#   8608            1035  24-04-2015          yogurt
#   19786           1035  24-04-2015          yogurt
#   24757           1035  24-04-2015      rolls/buns),
#  ((1035, '25-06-2014'),
#          Member_number        Date    itemDescription
#   14818           1035  25-06-2014         whole milk
#   30967           1035  25-06-2014  frozen vegetables),
#  ((1036, '20-01-2014'),
#          Member_number        Date        itemDescription
#   12551           1036  20-01-2014  fruit/vegetable juice
#   28700           1036  20-01-2014                vinegar),
#  ((1037, '06-06-2014'),
#          Member_number        Date itemDescription
#   10306           1037  06-06-2014    citrus fruit
#   26455           1037  06-06-2014   shopping bags
#   34522           1037  06-06-2014     chewing gum
#   35344           1037  06-06-2014        cake bar),
#  ((1037, '16-12-2015'),
#          Member_number        Date itemDescription
#   5160            1037  16-12-2015     frankfurter
#   21309           1037  16-12-2015          yogurt
#   36344           1037  16-12-2015     canned beer),
#  ((1037, '24-02-2014'),
#          Member_number        Date itemDescription
#   14012           1037  24-02-2014  tropical fruit
#   30161           1037  24-02-2014     white bread
#   34142           1037  24-02-2014      rolls/buns),
#  ((1038, '02-04-2015'),
#          Member_number        Date     itemDescription
#   4136            1038  02-04-2015          whole milk
#   20285           1038  02-04-2015           pip fruit
#   32605           1038  02-04-2015  whipped/sour cream),
#  ((1038, '10-04-2015'),
#          Member_number        Date      itemDescription
#   2761            1038  10-04-2015     other vegetables
#   18910           1038  10-04-2015  specialty chocolate),
#  ((1038, '14-12-2015'),
#          Member_number        Date        itemDescription
#   5772            1038  14-12-2015  Instant food products
#   15895           1038  14-12-2015     whipped/sour cream
#   21921           1038  14-12-2015                 butter
#   32044           1038  14-12-2015               cake bar),
#  ((1038, '21-02-2015'),
#          Member_number        Date        itemDescription
#   5568            1038  21-02-2015                sausage
#   7785            1038  21-02-2015                   pork
#   21717           1038  21-02-2015                 butter
#   23934           1038  21-02-2015             whole milk
#   36752           1038  21-02-2015  fruit/vegetable juice),
#  ((1038, '23-04-2015'),
#          Member_number        Date itemDescription
#   3478            1038  23-04-2015       pip fruit
#   19627           1038  23-04-2015           herbs
#   34785           1038  23-04-2015    frozen meals),
#  ((1038, '28-01-2014'),
#          Member_number        Date itemDescription
#   11697           1038  28-01-2014       margarine
#   27846           1038  28-01-2014         napkins),
#  ((1039, '31-05-2015'),
#          Member_number        Date itemDescription
#   3584            1039  31-05-2015     salty snack
#   19733           1039  31-05-2015      rolls/buns),
#  ((1040, '03-09-2014'),
#          Member_number        Date itemDescription
#   10446           1040  03-09-2014      whole milk
#   26595           1040  03-09-2014           pasta
#   35484           1040  03-09-2014      rolls/buns),
#  ((1040, '14-06-2014'),
#          Member_number        Date itemDescription
#   9941            1040  14-06-2014          yogurt
#   26090           1040  14-06-2014      rolls/buns),
#  ((1040, '24-10-2014'),
#          Member_number        Date  itemDescription
#   11817           1040  24-10-2014  root vegetables
#   27966           1040  24-10-2014      white bread),
#  ((1040, '26-11-2015'),
#          Member_number        Date            itemDescription
#   4774            1040  26-11-2015             tropical fruit
#   8326            1040  26-11-2015                    chicken
#   20923           1040  26-11-2015                     onions
#   24475           1040  26-11-2015  packaged fruit/vegetables),
#  ((1041, '02-04-2015'),
#          Member_number        Date itemDescription
#   3739            1041  02-04-2015  hamburger meat
#   19888           1041  02-04-2015          yogurt),
#  ((1041, '07-07-2014'),
#          Member_number        Date itemDescription
#   15462           1041  07-07-2014        prosecco
#   31611           1041  07-07-2014         dessert),
#  ((1041, '13-06-2014'),
#          Member_number        Date    itemDescription
#   8749            1041  13-06-2014            chicken
#   24898           1041  13-06-2014  frozen vegetables
#   36825           1041  13-06-2014              candy),
#  ((1041, '29-06-2014'),
#          Member_number        Date itemDescription
#   11412           1041  29-06-2014  tropical fruit
#   27561           1041  29-06-2014     brown bread
#   38655           1041  29-06-2014      whole milk),
#  ((1042, '12-02-2015'),
#          Member_number        Date itemDescription
#   461             1042  12-02-2015            beef
#   16610           1042  12-02-2015         dessert),
#  ((1042, '16-10-2015'),
#          Member_number        Date   itemDescription
#   6704            1042  16-10-2015        whole milk
#   22853           1042  16-10-2015  other vegetables),
#  ((1042, '22-05-2015'),
#          Member_number        Date itemDescription
#   6382            1042  22-05-2015    citrus fruit
#   22531           1042  22-05-2015   bottled water),
#  ((1043, '10-01-2015'),
#          Member_number        Date itemDescription
#   345             1043  10-01-2015    citrus fruit
#   16494           1043  10-01-2015      rolls/buns
#   32556           1043  10-01-2015      whole milk),
#  ((1043, '14-03-2014'),
#          Member_number        Date itemDescription
#   8996            1043  14-03-2014  tropical fruit
#   25145           1043  14-03-2014   sliced cheese),
#  ((1043, '16-06-2014'),
#          Member_number        Date        itemDescription
#   12915           1043  16-06-2014                napkins
#   29064           1043  16-06-2014             whole milk
#   36914           1043  16-06-2014  chocolate marshmallow),
#  ((1044, '09-02-2015'),
#          Member_number        Date   itemDescription
#   1488            1044  09-02-2015    tropical fruit
#   17637           1044  09-02-2015  other vegetables),
#  ((1044, '25-10-2015'),
#          Member_number        Date  itemDescription
#   6041            1044  25-10-2015  root vegetables
#   22190           1044  25-10-2015             curd),
#  ((1045, '10-04-2014'),
#          Member_number        Date        itemDescription
#   11497           1045  10-04-2014  fruit/vegetable juice
#   27646           1045  10-04-2014    specialty chocolate
#   38740           1045  10-04-2014  Instant food products),
#  ((1045, '12-01-2014'),
#          Member_number        Date  itemDescription
#   13823           1045  12-01-2014  root vegetables
#   29972           1045  12-01-2014           yogurt
#   33953           1045  12-01-2014           butter
#   37270           1045  12-01-2014           yogurt),
#  ((1045, '25-11-2015'),
#          Member_number        Date itemDescription
#   1083            1045  25-11-2015         chicken
#   17232           1045  25-11-2015          onions),
#  ((1046, '18-06-2015'),
#          Member_number        Date itemDescription
#   4314            1046  18-06-2015      whole milk
#   20463           1046  18-06-2015          pastry),
#  ((1046, '24-06-2015'),
#          Member_number        Date itemDescription
#   6204            1046  24-06-2015            pork
#   22353           1046  24-06-2015   bottled water),
#  ((1047, '04-01-2015'),
#          Member_number        Date itemDescription
#   4452            1047  04-01-2015            curd
#   20601           1047  04-01-2015            soda),
#  ((1047, '09-08-2015'),
#          Member_number        Date itemDescription
#   1954            1047  09-08-2015   sweet spreads
#   18103           1047  09-08-2015          butter),
#  ((1047, '17-12-2014'),
#          Member_number        Date itemDescription
#   15634           1047  17-12-2014       pip fruit
#   31783           1047  17-12-2014            soda),
#  ((1048, '06-10-2015'),
#          Member_number        Date itemDescription
#   3661            1048  06-10-2015      rolls/buns
#   8632            1048  06-10-2015  condensed milk
#   19810           1048  06-10-2015      whole milk
#   24781           1048  06-10-2015            soda),
#  ((1048, '18-10-2015'),
#          Member_number        Date itemDescription
#   2734            1048  18-10-2015      rolls/buns
#   18883           1048  18-10-2015  tropical fruit),
#  ((1049, '01-07-2015'),
#          Member_number        Date itemDescription
#   1961            1049  01-07-2015          butter
#   18110           1049  01-07-2015      whole milk),
#  ((1049, '04-08-2015'),
#          Member_number        Date itemDescription
#   6443            1049  04-08-2015     white bread
#   22592           1049  04-08-2015           candy),
#  ((1049, '05-09-2015'),
#          Member_number        Date itemDescription
#   2747            1049  05-09-2015     frankfurter
#   18896           1049  05-09-2015           herbs),
#  ((1049, '07-01-2014'),
#          Member_number        Date itemDescription
#   11671           1049  07-01-2014   specialty bar
#   27820           1049  07-01-2014       margarine),
#  ((1050, '04-05-2015'),
#          Member_number        Date itemDescription
#   1113            1050  04-05-2015            meat
#   17262           1050  04-05-2015      whole milk),
#  ((1050, '06-03-2014'),
#          Member_number        Date         itemDescription
#   13652           1050  06-03-2014  house keeping products
#   29801           1050  06-03-2014                  yogurt),
#  ((1050, '10-10-2014'),
#          Member_number        Date     itemDescription
#   12818           1050  10-10-2014  whipped/sour cream
#   28967           1050  10-10-2014    hygiene articles),
#  ((1050, '12-10-2014'),
#          Member_number        Date   itemDescription
#   10500           1050  12-10-2014          UHT-milk
#   26649           1050  12-10-2014  other vegetables
#   35538           1050  12-10-2014            dishes),
#  ((1050, '15-02-2014'),
#          Member_number        Date itemDescription
#   15288           1050  15-02-2014         waffles
#   31437           1050  15-02-2014       beverages),
#  ((1050, '30-05-2014'),
#          Member_number        Date itemDescription
#   13711           1050  30-05-2014           pasta
#   29860           1050  30-05-2014          yogurt
#   37158           1050  30-05-2014        cat food),
#  ((1051, '10-11-2015'),
#          Member_number        Date itemDescription
#   3645            1051  10-11-2015            fish
#   8616            1051  10-11-2015  tropical fruit
#   19794           1051  10-11-2015  red/blush wine
#   24765           1051  10-11-2015   cream cheese ),
#  ((1051, '12-08-2015'),
#          Member_number        Date   itemDescription
#   5900            1051  12-08-2015  other vegetables
#   16023           1051  12-08-2015              soda
#   22049           1051  12-08-2015        rolls/buns
#   32172           1051  12-08-2015            dishes),
#  ((1051, '12-10-2015'),
#          Member_number        Date           itemDescription
#   3717            1051  12-10-2015            tropical fruit
#   8688            1051  12-10-2015          other vegetables
#   19866           1051  12-10-2015            hamburger meat
#   24837           1051  12-10-2015                   popcorn
#   36764           1051  12-10-2015  female sanitary products),
#  ((1051, '13-01-2014'),
#          Member_number        Date itemDescription
#   11889           1051  13-01-2014  hamburger meat
#   28038           1051  13-01-2014    bottled beer),
#  ((1051, '17-09-2014'),
#          Member_number        Date    itemDescription
#   10800           1051  17-09-2014               pork
#   26949           1051  17-09-2014             coffee
#   34207           1051  17-09-2014  frozen vegetables),
#  ((1051, '26-12-2014'),
#          Member_number        Date itemDescription
#   33006           1051  26-12-2014   shopping bags
#   37557           1051  26-12-2014   shopping bags),
#  ((1052, '04-01-2014'),
#          Member_number        Date itemDescription
#   12167           1052  04-01-2014            beef
#   28316           1052  04-01-2014   shopping bags),
#  ((1052, '05-12-2014'),
#          Member_number        Date itemDescription
#   11735           1052  05-12-2014            soda
#   27884           1052  05-12-2014  hamburger meat),
#  ((1052, '06-07-2015'),
#          Member_number        Date itemDescription
#   4538            1052  06-07-2015     butter milk
#   8090            1052  06-07-2015          yogurt
#   20687           1052  06-07-2015          yogurt
#   24239           1052  06-07-2015       margarine),
#  ((1052, '13-10-2014'),
#          Member_number        Date itemDescription
#   12042           1052  13-10-2014            soda
#   28191           1052  13-10-2014      whole milk),
#  ((1052, '15-01-2014'),
#          Member_number        Date  itemDescription
#   13141           1052  15-01-2014  root vegetables
#   29290           1052  15-01-2014           grapes),
#  ((1052, '15-05-2015'),
#          Member_number        Date     itemDescription
#   6276            1052  15-05-2015         frankfurter
#   22425           1052  15-05-2015  whipped/sour cream),
#  ((1052, '20-11-2014'),
#          Member_number        Date itemDescription
#   9888            1052  20-11-2014   bottled water
#   26037           1052  20-11-2014     chewing gum),
#  ((1052, '24-03-2014'),
#          Member_number        Date itemDescription
#   10409           1052  24-03-2014         chicken
#   26558           1052  24-03-2014       beverages
#   35447           1052  24-03-2014          coffee),
#  ((1052, '27-10-2015'),
#          Member_number        Date   itemDescription
#   5536            1052  27-10-2015              pork
#   7753            1052  27-10-2015  other vegetables
#   21685           1052  27-10-2015            yogurt
#   23902           1052  27-10-2015     shopping bags
#   35871           1052  27-10-2015       soft cheese
#   36720           1052  27-10-2015         detergent),
#  ((1052, '29-09-2014'),
#          Member_number        Date itemDescription
#   9882            1052  29-09-2014          butter
#   26031           1052  29-09-2014        dog food),
#  ((1053, '05-11-2014'),
#          Member_number        Date    itemDescription
#   9241            1053  05-11-2014            chicken
#   25390           1053  05-11-2014  frozen vegetables),
#  ((1053, '09-07-2015'),
#          Member_number        Date itemDescription
#   1325            1053  09-07-2015  hamburger meat
#   17474           1053  09-07-2015          pastry),
#  ((1053, '10-12-2014'),
#          Member_number        Date   itemDescription
#   15571           1053  10-12-2014  other vegetables
#   31720           1053  10-12-2014        whole milk),
#  ((1053, '16-05-2014'),
#          Member_number        Date itemDescription
#   12001           1053  16-05-2014         waffles
#   28150           1053  16-05-2014      rolls/buns),
#  ((1053, '23-05-2014'),
#          Member_number        Date itemDescription
#   14624           1053  23-05-2014      whole milk
#   30773           1053  23-05-2014           sugar),
#  ((1053, '30-04-2014'),
#          Member_number        Date itemDescription
#   14551           1053  30-04-2014            soda
#   30700           1053  30-04-2014            soda),
#  ((1054, '02-09-2015'),
#          Member_number        Date itemDescription
#   6150            1054  02-09-2015    bottled beer
#   22299           1054  02-09-2015             oil),
#  ((1054, '04-10-2015'),
#          Member_number        Date itemDescription
#   340             1054  04-10-2015     frankfurter
#   16489           1054  04-10-2015    citrus fruit
#   32551           1054  04-10-2015       margarine),
#  ((1054, '16-01-2014'),
#          Member_number        Date        itemDescription
#   33009           1054  16-01-2014                   soda
#   37560           1054  16-01-2014  fruit/vegetable juice),
#  ((1054, '21-10-2015'),
#          Member_number        Date   itemDescription
#   3140            1054  21-10-2015        photo/film
#   19289           1054  21-10-2015  other vegetables),
#  ((1055, '05-08-2014'),
#          Member_number        Date itemDescription
#   15605           1055  05-08-2014            pork
#   31754           1055  05-08-2014      white wine),
#  ((1055, '25-05-2015'),
#          Member_number        Date itemDescription
#   2285            1055  25-05-2015   bottled water
#   8016            1055  25-05-2015          yogurt
#   18434           1055  25-05-2015      newspapers
#   24165           1055  25-05-2015            soda),
#  ((1056, '09-11-2015'),
#          Member_number        Date     itemDescription
#   2745            1056  09-11-2015  whipped/sour cream
#   18894           1056  09-11-2015        meat spreads),
#  ((1056, '13-09-2015'),
#          Member_number        Date   itemDescription
#   1870            1056  13-09-2015         pip fruit
#   18019           1056  13-09-2015  other vegetables),
#  ((1056, '24-09-2014'),
#          Member_number        Date itemDescription
#   9526            1056  24-09-2014             ham
#   25675           1056  24-09-2014      whole milk),
#  ((1057, '05-03-2014'),
#          Member_number        Date     itemDescription
#   33196           1057  05-03-2014         salty snack
#   37747           1057  05-03-2014  pickled vegetables),
#  ((1057, '06-01-2014'),
#          Member_number        Date itemDescription
#   13923           1057  06-01-2014            soda
#   30072           1057  06-01-2014   domestic eggs
#   34053           1057  06-01-2014   sliced cheese
#   37370           1057  06-01-2014            soda),
#  ((1057, '08-06-2014'),
#          Member_number        Date itemDescription
#   15276           1057  08-06-2014  tropical fruit
#   31425           1057  08-06-2014        UHT-milk),
#  ((1058, '06-04-2015'),
#          Member_number        Date itemDescription
#   3580            1058  06-04-2015         sausage
#   19729           1058  06-04-2015   bottled water),
#  ((1058, '07-08-2014'),
#          Member_number        Date  itemDescription
#   9867            1058  07-08-2014           yogurt
#   26016           1058  07-08-2014  root vegetables),
#  ((1058, '10-11-2015'),
#          Member_number        Date   itemDescription
#   258             1058  10-11-2015   root vegetables
#   16407           1058  10-11-2015  other vegetables),
#  ((1058, '24-05-2014'),
#          Member_number        Date   itemDescription
#   13083           1058  24-05-2014           chicken
#   29232           1058  24-05-2014  other vegetables),
#  ((1059, '11-06-2014'),
#          Member_number        Date itemDescription
#   33252           1059  11-06-2014         dessert
#   37803           1059  11-06-2014   spread cheese),
#  ((1059, '14-06-2014'),
#          Member_number        Date  itemDescription
#   13685           1059  14-06-2014          sausage
#   29834           1059  14-06-2014      salty snack
#   37132           1059  14-06-2014  cling film/bags),
#  ((1061, '05-09-2015'),
#          Member_number        Date        itemDescription
#   53              1061  05-09-2015             whole milk
#   7130            1061  05-09-2015         tropical fruit
#   16202           1061  05-09-2015        root vegetables
#   23279           1061  05-09-2015  Instant food products
#   36141           1061  05-09-2015              margarine),
#  ((1061, '17-03-2014'),
# ...
#          Member_number        Date itemDescription
#   3213            1256  02-08-2015         sausage
#   19362           1256  02-08-2015          coffee),
#  ((1256, '07-11-2014'),
#          Member_number        Date itemDescription
#   15690           1256  07-11-2014         berries
#   31839           1256  07-11-2014   domestic eggs),
#  ((1256, '14-10-2014'),
#          Member_number        Date   itemDescription
#   11888           1256  14-10-2014             sugar
#   28037           1256  14-10-2014  other vegetables),
#  ((1256, '17-06-2014'),
#          Member_number        Date itemDescription
#   33363           1256  17-06-2014             tea
#   37914           1256  17-06-2014          coffee),
#  ((1256, '29-08-2015'),
#          Member_number        Date itemDescription
#   5808            1256  29-08-2015        UHT-milk
#   15931           1256  29-08-2015           herbs
#   21957           1256  29-08-2015          butter
#   32080           1256  29-08-2015             oil),
#  ((1257, '16-09-2014'),
#          Member_number        Date itemDescription
#   9656            1257  16-09-2014      rolls/buns
#   25805           1257  16-09-2014          yogurt),
#  ((1257, '19-05-2014'),
#          Member_number        Date itemDescription
#   15668           1257  19-05-2014  frozen dessert
#   31817           1257  19-05-2014   cream cheese ),
#  ((1258, '04-05-2014'),
#          Member_number        Date itemDescription
#   14872           1258  04-05-2014          yogurt
#   31021           1258  04-05-2014          coffee),
#  ((1258, '09-08-2014'),
#          Member_number        Date        itemDescription
#   13792           1258  09-08-2014             rolls/buns
#   29941           1258  09-08-2014  fruit/vegetable juice
#   33922           1258  09-08-2014      frozen vegetables
#   37239           1258  09-08-2014     whipped/sour cream),
#  ((1259, '10-06-2014'),
#          Member_number        Date itemDescription
#   11011           1259  10-06-2014  hamburger meat
#   27160           1259  10-06-2014          coffee),
#  ((1259, '20-04-2014'),
#          Member_number        Date itemDescription
#   14652           1259  20-04-2014      whole milk
#   30801           1259  20-04-2014   shopping bags),
#  ((1259, '20-09-2015'),
#          Member_number        Date itemDescription
#   6315            1259  20-09-2015       ice cream
#   22464           1259  20-09-2015      whole milk),
#  ((1259, '21-11-2015'),
#          Member_number        Date itemDescription
#   5769            1259  21-11-2015         sausage
#   15892           1259  21-11-2015          grapes
#   21918           1259  21-11-2015   sliced cheese
#   32041           1259  21-11-2015         napkins),
#  ((1259, '24-06-2014'),
#          Member_number        Date        itemDescription
#   12442           1259  24-06-2014  fruit/vegetable juice
#   28591           1259  24-06-2014                berries),
#  ((1259, '27-11-2015'),
#          Member_number        Date  itemDescription
#   1164            1259  27-11-2015             pork
#   17313           1259  27-11-2015  root vegetables),
#  ((1260, '04-10-2014'),
#          Member_number        Date itemDescription
#   15180           1260  04-10-2014       pip fruit
#   31329           1260  04-10-2014   shopping bags),
#  ((1260, '09-07-2014'),
#          Member_number        Date itemDescription
#   13100           1260  09-07-2014         sausage
#   29249           1260  09-07-2014            curd),
#  ((1261, '06-10-2014'),
#          Member_number        Date    itemDescription
#   13814           1261  06-10-2014         whole milk
#   29963           1261  06-10-2014      domestic eggs
#   33944           1261  06-10-2014  canned vegetables
#   37261           1261  06-10-2014     flower (seeds)),
#  ((1261, '21-05-2015'),
#          Member_number        Date itemDescription
#   3833            1261  21-05-2015      rolls/buns
#   15746           1261  21-05-2015     hard cheese
#   19982           1261  21-05-2015      rolls/buns
#   31895           1261  21-05-2015           flour),
#  ((1262, '12-07-2014'),
#          Member_number        Date  itemDescription
#   8769            1262  12-07-2014  organic sausage
#   24918           1262  12-07-2014     frozen meals
#   36845           1262  12-07-2014            sugar),
#  ((1262, '22-07-2014'),
#          Member_number        Date     itemDescription
#   9403            1262  22-07-2014          whole milk
#   25552           1262  22-07-2014              onions
#   32739           1262  22-07-2014  pickled vegetables),
#  ((1263, '11-05-2014'),
#          Member_number        Date   itemDescription
#   9561            1263  11-05-2014      citrus fruit
#   25710           1263  11-05-2014  other vegetables),
#  ((1263, '19-10-2014'),
#          Member_number        Date itemDescription
#   12520           1263  19-10-2014    frozen meals
#   28669           1263  19-10-2014    bottled beer),
#  ((1264, '07-12-2015'),
#          Member_number        Date      itemDescription
#   4480            1264  07-12-2015       tropical fruit
#   8032            1264  07-12-2015               yogurt
#   20629           1264  07-12-2015  semi-finished bread
#   24181           1264  07-12-2015                 soda),
#  ((1264, '11-12-2014'),
#          Member_number        Date itemDescription
#   12344           1264  11-12-2014  tropical fruit
#   28493           1264  11-12-2014     white bread
#   38570           1264  11-12-2014          butter),
#  ((1264, '12-10-2015'),
#          Member_number        Date itemDescription
#   405             1264  12-10-2015   specialty bar
#   16554           1264  12-10-2015  tropical fruit),
#  ((1264, '17-11-2015'),
#          Member_number        Date itemDescription
#   470             1264  17-11-2015   bottled water
#   16619           1264  17-11-2015          pastry),
#  ((1264, '23-11-2015'),
#          Member_number        Date itemDescription
#   862             1264  23-11-2015           sugar
#   17011           1264  23-11-2015            curd),
#  ((1264, '30-07-2015'),
#          Member_number        Date   itemDescription
#   5854            1264  30-07-2015           sausage
#   15977           1264  30-07-2015  other vegetables
#   22003           1264  30-07-2015    tropical fruit
#   32126           1264  30-07-2015        mayonnaise),
#  ((1265, '01-02-2014'),
#          Member_number        Date   itemDescription
#   10413           1265  01-02-2014  other vegetables
#   26562           1265  01-02-2014        whole milk
#   35451           1265  01-02-2014              soda),
#  ((1265, '03-10-2015'),
#          Member_number        Date itemDescription
#   6572            1265  03-10-2015            pork
#   22721           1265  03-10-2015     brown bread),
#  ((1265, '05-12-2014'),
#          Member_number        Date  itemDescription
#   10355           1265  05-12-2014         UHT-milk
#   26504           1265  05-12-2014      canned fish
#   34571           1265  05-12-2014  root vegetables
#   35393           1265  05-12-2014          waffles),
#  ((1265, '07-03-2015'),
#          Member_number        Date      itemDescription
#   2154            1265  07-03-2015        cream cheese
#   7531            1265  07-03-2015            pip fruit
#   7885            1265  07-03-2015         citrus fruit
#   8487            1265  07-03-2015              chicken
#   18303           1265  07-03-2015     other vegetables
#   23680           1265  07-03-2015                 curd
#   24034           1265  07-03-2015  specialty chocolate
#   24636           1265  07-03-2015               pastry),
#  ((1265, '13-04-2015'),
#          Member_number        Date itemDescription
#   6314            1265  13-04-2015            pork
#   22463           1265  13-04-2015          yogurt),
#  ((1265, '19-01-2015'),
#          Member_number        Date   itemDescription
#   6708            1265  19-01-2015    hamburger meat
#   22857           1265  19-01-2015  other vegetables
#   32301           1265  19-01-2015     domestic eggs),
#  ((1265, '29-09-2015'),
#          Member_number        Date itemDescription
#   3405            1265  29-09-2015   shopping bags
#   19554           1265  29-09-2015  tropical fruit
#   34712           1265  29-09-2015  red/blush wine),
#  ((1266, '27-08-2014'),
#          Member_number        Date   itemDescription
#   11187           1266  27-08-2014  other vegetables
#   27336           1266  27-08-2014     sliced cheese),
#  ((1267, '15-05-2014'),
#          Member_number        Date itemDescription
#   15639           1267  15-05-2014          butter
#   31788           1267  15-05-2014      whole milk),
#  ((1268, '19-10-2014'),
#          Member_number        Date itemDescription
#   12719           1268  19-10-2014             oil
#   28868           1268  19-10-2014     canned fish),
#  ((1268, '22-07-2014'),
#          Member_number        Date  itemDescription
#   14078           1268  22-07-2014       whole milk
#   30227           1268  22-07-2014  misc. beverages),
#  ((1268, '26-09-2014'),
#          Member_number        Date itemDescription
#   13025           1268  26-09-2014      white wine
#   29174           1268  26-09-2014          sauces),
#  ((1268, '30-01-2014'),
#          Member_number        Date   itemDescription
#   12928           1268  30-01-2014  other vegetables
#   29077           1268  30-01-2014         margarine
#   36927           1268  30-01-2014       brown bread),
#  ((1269, '07-10-2014'),
#          Member_number        Date itemDescription
#   10839           1269  07-10-2014  red/blush wine
#   26988           1269  07-10-2014    frozen meals
#   34246           1269  07-10-2014    canned fruit),
#  ((1269, '12-09-2015'),
#          Member_number        Date   itemDescription
#   5783            1269  12-09-2015  other vegetables
#   15906           1269  12-09-2015            liquor
#   21932           1269  12-09-2015        whole milk
#   32055           1269  12-09-2015       butter milk),
#  ((1269, '14-04-2014'),
#          Member_number        Date    itemDescription
#   15112           1269  14-04-2014         rolls/buns
#   31261           1269  14-04-2014  seasonal products),
#  ((1269, '24-04-2014'),
#          Member_number        Date  itemDescription
#   9271            1269  24-04-2014   tropical fruit
#   25420           1269  24-04-2014  root vegetables),
#  ((1269, '30-09-2015'),
#          Member_number        Date   itemDescription
#   1734            1269  30-09-2015  other vegetables
#   17883           1269  30-09-2015        whole milk
#   35987           1269  30-09-2015          softener),
#  ((1270, '03-02-2015'),
#          Member_number        Date itemDescription
#   1565            1270  03-02-2015    citrus fruit
#   17714           1270  03-02-2015         cereals),
#  ((1270, '12-07-2014'),
#          Member_number        Date         itemDescription
#   12179           1270  12-07-2014                cake bar
#   28328           1270  12-07-2014  flower soil/fertilizer),
#  ((1270, '25-04-2015'),
#          Member_number        Date itemDescription
#   2726            1270  25-04-2015            pork
#   18875           1270  25-04-2015         napkins),
#  ((1272, '27-07-2014'),
#          Member_number        Date itemDescription
#   14780           1272  27-07-2014   specialty bar
#   30929           1272  27-07-2014         cleaner),
#  ((1273, '04-05-2015'),
#          Member_number        Date   itemDescription
#   980             1273  04-05-2015  artif. sweetener
#   17129           1273  04-05-2015        whole milk),
#  ((1273, '31-01-2015'),
#          Member_number        Date itemDescription
#   988             1273  31-01-2015            pork
#   17137           1273  31-01-2015          pastry),
#  ((1274, '10-07-2014'),
#          Member_number        Date   itemDescription
#   9372            1274  10-07-2014            coffee
#   25521           1274  10-07-2014  other vegetables
#   32708           1274  10-07-2014  specialty cheese),
#  ((1274, '16-05-2014'),
#          Member_number        Date itemDescription
#   9693            1274  16-05-2014         dessert
#   25842           1274  16-05-2014      rolls/buns),
#  ((1274, '25-04-2014'),
#          Member_number        Date itemDescription
#   11527           1274  25-04-2014         tidbits
#   27676           1274  25-04-2014   cream cheese ),
#  ((1275, '04-06-2015'),
#          Member_number        Date   itemDescription
#   1589            1275  04-06-2015              curd
#   17738           1275  04-06-2015  hygiene articles),
#  ((1275, '06-11-2014'),
#          Member_number        Date itemDescription
#   33257           1275  06-11-2014      rolls/buns
#   37808           1275  06-11-2014     dental care),
#  ((1275, '07-05-2015'),
#          Member_number        Date  itemDescription
#   5241            1275  07-05-2015  root vegetables
#   21390           1275  07-05-2015           butter
#   36425           1275  07-05-2015          dessert),
#  ((1275, '10-06-2014'),
#          Member_number        Date itemDescription
#   12416           1275  10-06-2014    citrus fruit
#   28565           1275  10-06-2014          pastry),
#  ((1275, '11-04-2015'),
#          Member_number        Date itemDescription
#   6460            1275  11-04-2015            salt
#   22609           1275  11-04-2015    citrus fruit),
#  ((1275, '16-07-2015'),
#          Member_number        Date   itemDescription
#   2401            1275  16-07-2015  other vegetables
#   18550           1275  16-07-2015        whole milk),
#  ((1275, '17-02-2015'),
#          Member_number        Date itemDescription
#   2426            1275  17-02-2015         sausage
#   18575           1275  17-02-2015          onions
#   36994           1275  17-02-2015         mustard),
#  ((1275, '18-01-2014'),
#          Member_number        Date         itemDescription
#   13824           1275  18-01-2014  frozen potato products
#   29973           1275  18-01-2014           domestic eggs
#   33954           1275  18-01-2014           shopping bags
#   37271           1275  18-01-2014             butter milk),
#  ((1275, '18-10-2015'),
#          Member_number        Date      itemDescription
#   2372            1275  18-10-2015          white bread
#   18521           1275  18-10-2015  specialty chocolate),
#  ((1275, '19-06-2014'),
#          Member_number        Date itemDescription
#   12623           1275  19-06-2014       ice cream
#   28772           1275  19-06-2014          butter),
#  ((1276, '07-06-2014'),
#          Member_number        Date         itemDescription
#   33115           1276  07-06-2014                 dessert
#   37666           1276  07-06-2014  house keeping products),
#  ((1276, '23-11-2015'),
#          Member_number        Date itemDescription
#   5691            1276  23-11-2015  condensed milk
#   21840           1276  23-11-2015     hard cheese),
#  ((1276, '26-03-2015'),
#          Member_number        Date itemDescription
#   6120            1276  26-03-2015     hard cheese
#   22269           1276  26-03-2015          yogurt),
#  ((1276, '28-04-2015'),
#          Member_number        Date itemDescription
#   3965            1276  28-04-2015         sausage
#   15878           1276  28-04-2015      whole milk
#   20114           1276  28-04-2015      rolls/buns
#   32027           1276  28-04-2015    bottled beer),
#  ((1276, '28-08-2015'),
#          Member_number        Date      itemDescription
#   5222            1276  28-08-2015           whole milk
#   21371           1276  28-08-2015        cream cheese
#   36406           1276  28-08-2015  semi-finished bread),
#  ((1277, '01-12-2015'),
#          Member_number        Date itemDescription
#   3056            1277  01-12-2015         sausage
#   19205           1277  01-12-2015      rolls/buns),
#  ((1277, '02-03-2015'),
#          Member_number        Date itemDescription
#   3100            1277  02-03-2015     frankfurter
#   19249           1277  02-03-2015   shopping bags),
#  ((1277, '07-06-2015'),
#          Member_number        Date itemDescription
#   3997            1277  07-06-2015      photo/film
#   5008            1277  07-06-2015      whole milk
#   16047           1277  07-06-2015          yogurt
#   20146           1277  07-06-2015      whole milk
#   21157           1277  07-06-2015     white bread
#   32196           1277  07-06-2015      pot plants
#   36192           1277  07-06-2015         dessert),
#  ...]

# %% [markdown]
# For all itemDescriptions associated with each Member_number + Date GroupBy, display in list format

# %%
transactions = []
for item in theList:
    transactions.append(item[1]['itemDescription'].tolist())
print(transactions)
# Out:
# [['sausage', 'whole milk', 'semi-finished bread', 'yogurt'], ['whole milk', 'pastry', 'salty snack'], ['canned beer', 'misc. beverages'], ['sausage', 'hygiene articles'], ['soda', 'pickled vegetables'], ['frankfurter', 'curd'], ['sausage', 'whole milk', 'rolls/buns'], ['whole milk', 'soda'], ['beef', 'white bread'], ['frankfurter', 'soda', 'whipped/sour cream'], ['frozen vegetables', 'other vegetables'], ['butter', 'whole milk'], ['tropical fruit', 'sugar'], ['butter milk', 'specialty chocolate'], ['sausage', 'rolls/buns'], ['root vegetables', 'detergent'], ['frozen meals', 'dental care'], ['rolls/buns', 'rolls/buns'], ['dish cleaner', 'cling film/bags'], ['canned beer', 'frozen fish'], ['other vegetables', 'hygiene articles'], ['pip fruit', 'whole milk', 'tropical fruit'], ['rolls/buns', 'red/blush wine', 'chocolate'], ['other vegetables', 'shopping bags'], ['whole milk', 'chocolate', 'packaged fruit/vegetables', 'rolls/buns'], ['root vegetables', 'whole milk', 'pastry'], ['rolls/buns', 'rolls/buns'], ['whipped/sour cream', 'margarine'], ['bottled water', 'softener', 'rolls/buns'], ['whole milk', 'rice'], ['shopping bags', 'skin care'], ['whole milk', 'frankfurter', 'chicken', 'frankfurter', 'flour', 'chocolate', 'bottled beer', 'rolls/buns'], ['hamburger meat', 'liquor (appetizer)', 'liver loaf', 'dessert'], ['tropical fruit', 'soda', 'yogurt', 'root vegetables', 'yogurt', 'domestic eggs', 'white wine', 'photo/film'], ['herbs', 'yogurt', 'newspapers'], ['tropical fruit', 'yogurt'], ['pastry', 'ketchup'], ['canned fish', 'cocoa drinks'], ['pip fruit', 'coffee', 'UHT-milk'], ['kitchen towels', 'sliced cheese'], ['bottled water', 'specialty bar'], ['frankfurter', 'bottled water'], ['pip fruit', 'candles', 'rolls/buns'], ['curd cheese', 'pastry'], ['whole milk', 'frankfurter', 'candles', 'grapes', 'herbs', 'other vegetables', 'yogurt'], ['citrus fruit', 'candy', 'bottled water', 'rolls/buns'], ['frankfurter', 'yogurt'], ['tropical fruit', 'root vegetables', 'rolls/buns', 'onions', 'shopping bags'], ['frozen vegetables', 'brown bread'], ['processed cheese', 'whole milk'], ['frozen meals', 'whole milk'], ['white bread', 'meat', 'domestic eggs', 'roll products '], ['root vegetables', 'mayonnaise'], ['other vegetables', 'mustard'], ['hard cheese', 'napkins', 'bottled water'], ['whole milk', 'candy'], ['tropical fruit', 'frozen vegetables'], ['mustard', 'whipped/sour cream'], ['whole milk', 'sausage', 'bottled beer', 'yogurt'], ['canned beer', 'cookware'], ['hamburger meat', 'butter milk'], ['whole milk', 'rolls/buns'], ['citrus fruit', 'whole milk'], ['salty snack', 'beef'], ['fruit/vegetable juice', 'rolls/buns', 'chocolate'], ['UHT-milk', 'bottled beer'], ['chicken', 'red/blush wine'], ['soft cheese', 'pip fruit'], ['rolls/buns', 'frankfurter', 'oil', 'pip fruit', 'mayonnaise'], ['brown bread', 'pet care'], ['other vegetables', 'rolls/buns'], ['yogurt', 'beef'], ['other vegetables', 'root vegetables'], ['soda', 'dessert', 'shopping bags'], ['curd', 'long life bakery product'], ['beverages', 'domestic eggs'], ['butter milk', 'root vegetables'], ['berries', 'cake bar'], ['hamburger meat', 'red/blush wine'], ['canned beer', 'shopping bags'], ['canned beer', 'spices', 'rolls/buns', 'frozen fish'], ['frozen meals', 'butter', 'newspapers', 'yogurt'], ['rolls/buns', 'baking powder'], ['liquor', 'curd', 'yogurt', 'tropical fruit'], ['sliced cheese', 'butter'], ['sausage', 'fruit/vegetable juice'], ['beef', 'napkins'], ['whole milk', 'whipped/sour cream'], ['whipped/sour cream', 'root vegetables', 'rolls/buns', 'packaged fruit/vegetables'], ['domestic eggs', 'soda'], ['chicken', 'frozen meals'], ['male cosmetics', 'curd'], ['white bread', 'bottled beer', 'yogurt', 'berries'], ['sausage', 'whipped/sour cream', 'specialty bar'], ['fish', 'root vegetables', 'tropical fruit', 'other vegetables'], ['coffee', 'shopping bags'], ['ham', 'cream cheese '], ['canned beer', 'UHT-milk'], ['sausage', 'dessert', 'rolls/buns', 'pickled vegetables'], ['fru ...

# %% [markdown]
# ## Generating Association Rules from Frequent Itemsets
#
# - Association rules are if/then statements that help discover relationships or patterns between datasets in various kinds of databases, including relational
#     - An association rule has 2 parts:
#         - Antecedent (if): Something that's found in the data
#         - Consequent (then): Item them is found in combination with the antecedent
#     - Itemset = List of all the items in the antecedent and sonsequent
#     - For example: {Bread, Eggs} --> {Milk}
#         - Antecedent = Bread, Eggs
#         - Consequent = Milk
#         - Itemset = {Bread, Eggs, Milk}
#
# - Association rules are created by thoroughly analyzing the data and looking for frequent if/then patterns
#     - In order to understand the strength of the association, we can use 3 different metrics: Support, Confidence, Lift
#     - Support (s) = Total # of transactions containing both ItemsetX and ItemsetY / Total # of transactions
#         - Support tells us how frequently an itemset is in all the transactions
#         - Support is used to help us identify the association rules that are worth considering in future analysis
#     - Confidence (c) = Total # of transactions containing both ItemsetX and ItemsetY / Transactions containing ItemsetX
#         - Confidence tells us the likelihood of occurrence of consequent (ItemsetY) in the purchase given that the purchase already has the antecedent (ItemsetX)
#     - Lift = (Transactions containing both ItemsetX and ItemsetY)/(Transactions containing ItemsetX) / Fraction of transactions containing ItemsetY
#         - Lift is the *lift* that ItemsetX gives to our confidence for having ItemsetY in the purchase
#         - Lift > 1 means high association between ItemsetY and ItemsetX....and the higher the lift, the more likely a customer will buy ItemsetY if they have already purchased ItemsetX
#         - Lift < 1 means low association between ItemsetY and ItemsetX
#
# - The goal of association rule mining is to find all the rules having a support and confidence greater than or equal to a threshold value

# %%
te = TransactionEncoder()
te_ary = te.fit(transactions).transform(transactions)
df = pd.DataFrame(te_ary, columns=te.columns_)
df
# Out:
#        Instant food products  UHT-milk  abrasive cleaner  artif. sweetener  \
# 0                      False     False             False             False
# 1                      False     False             False             False
# 2                      False     False             False             False
# 3                      False     False             False             False
# 4                      False     False             False             False
# ...                      ...       ...               ...               ...
# 14958                  False     False             False             False
# 14959                  False     False             False             False
# 14960                  False     False             False             False
# 14961                  False     False             False             False
# 14962                  False     False             False             False
#
#        baby cosmetics   bags  baking powder  bathroom cleaner   beef  berries  \
# 0               False  False          False             False  False    False
# 1               False  False          False             False  False    False
# 2               False  False          False             False  False    False
# 3               False  False          False             False  False    False
# 4               False  False          False             False  False    False
# ...               ...    ...            ...               ...    ...      ...
# 14958           False  False          False             False  False     True
# 14959           False  False          False             False  False    False
# 14960           False  False          False             False  False    False
# 14961           False  False          False             False  False    False
# 14962           False  False          False             False  False    False
#
#        ...  turkey  vinegar  waffles  whipped/sour cream  whisky  white bread  \
# 0      ...   False    False    False               False   False        False
# 1      ...   False    False    False               False   False        False
# 2      ...   False    False    False               False   False        False
# 3      ...   False    False    False               False   False        False
# 4      ...   False    False    False               False   False        False
# ...    ...     ...      ...      ...                 ...     ...          ...
# 14958  ...   False    False    False               False   False        False
# 14959  ...   False    False    False               False   False        False
# 14960  ...   False    False    False               False   False        False
# 14961  ...   False    False    False               False   False        False
# 14962  ...   False    False    False               False   False        False
#
#        white wine  whole milk  yogurt  zwieback
# 0           False        True    True     False
# 1           False        True   False     False
# 2           False       False   False     False
# 3           False       False   False     False
# 4           False       False   False     False
# ...           ...         ...     ...       ...
# 14958       False       False    True     False
# 14959       False       False   False     False
# 14960       False       False   False     False
# 14961       False       False   False     False
# 14962       False       False   False     False
#
# [14963 rows x 167 columns]

# %% [markdown]
# ### Apriori Algorithm
#
# - The Apriori algorithm is used to come up with a set of most important association rules to be considered
#     - The apriori algorithm uses frequent itemsets to generate the association rules and is based on the idea that a subset of a frequent itemset must also be a frequent itemset
#     - Frequent itemset = An itemset whose support is greater than or equal to a minimum threshold value (aka, minsup)
#     - The apriori algorithm is a brute force approach to finding frequent itemsets by forming all possible itemsets and checking the support value of each of these
# - To determine minsup, start at the highest and work down until you get a result set that is satisfactory for your data mining goals
#     - In the below example, I used a minsup of 0.01

# %%
frequent_itemsets = apriori(df, min_support=0.01, use_colnames=True, verbose=1)
frequent_itemsets
# Out:
# Processing 18 combinations | Sampling itemset size 3 2
#      support                        itemsets
# 0   0.021386                      (UHT-milk)
# 1   0.033950                          (beef)
# 2   0.021787                       (berries)
# 3   0.016574                     (beverages)
# 4   0.045312                  (bottled beer)
# ..       ...                             ...
# 64  0.010559  (other vegetables, rolls/buns)
# 65  0.014837  (other vegetables, whole milk)
# 66  0.013968        (rolls/buns, whole milk)
# 67  0.011629              (soda, whole milk)
# 68  0.011161            (whole milk, yogurt)
#
# [69 rows x 2 columns]

# %% [markdown]
# ### Generate_rules() to specify metric of interest and threshold
#
# - Once you have found your most important frequent itemsets using the apriori algorithm, us the generate_rules() function to specify the metric of interest and the according threshold
# - Currently implemented measures are confidence and lift
# - In the below example I chose a min_threshold of 0.1, so I was only interested in rules derived from the frequent itemsets only if the level of confidence is above the 10% threshold

# %%
association_rules(frequent_itemsets, metric="confidence", min_threshold=0.1)
# Out:
#           antecedents   consequents  antecedent support  consequent support  \
# 0  (other vegetables)  (whole milk)            0.122101            0.157923
# 1        (rolls/buns)  (whole milk)            0.110005            0.157923
# 2              (soda)  (whole milk)            0.097106            0.157923
# 3            (yogurt)  (whole milk)            0.085879            0.157923
#
#     support  confidence      lift  leverage  conviction
# 0  0.014837    0.121511  0.769430 -0.004446    0.958551
# 1  0.013968    0.126974  0.804028 -0.003404    0.964550
# 2  0.011629    0.119752  0.758296 -0.003707    0.956636
# 3  0.011161    0.129961  0.822940 -0.002401    0.967861

# %% [markdown]
# Looking at index 1 as an example, if a customer purchases rolls/buns they are 12.7% likely to also purchase whole milk
